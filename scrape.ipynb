# %%
import requests
import urllib.parse as urlencode

# %%
https://discourse.onlinedegree.iitm.ac.in/t/161071.json?track_visit=true&forceLoad=true

# %%
import requests

url = "https://discourse.onlinedegree.iitm.ac.in/t/161071.json?"
params = {
    "forceLoad": "true",
    "track_visit": "true"
}
# If you need to authenticate with a session cookie:
cookies = {"_forum_session": "_fbp=fb.2.1697298030139.448458330; _ga=GA1.1.2102012581.1731958303; _gcl_au=1.1.1266576419.1741963221; _ga_5HTJMW67XK=GS2.1.s1749277001$o18$g0$t1749277013$j48$l0$h0; _ga_08NPRH5L4M=GS2.1.s1749664007$o100$g0$t1749664531$j60$l0$h0; _t=ehkbgRrWgBYwICCpQ31ZpNUrWMMC9rp3v5iGT1PBSGsrlI7WrM%2BlgKMLGtc8eFJDN7QYdExTPQNvQGyyFnoZ2eMqD6zFYkO0edXBIXCEDgCT4gnT7EZmsAyRNUzs5%2BME5m4g3PAN6%2FX2qrEq60YIAqgR5m0DhW8fB5MYqfC4TGfiepo5fLGxteAAPUxHBn%2BScvG3I6oVXI6STwjSI9CS%2FC4r427WSecndDi2irVu%2BWGIsO6jL%2FLts%2B693SkPhir3bY84MtdDDct7yY0veMHBWi%2FxIPVHQn%2B%2FNVnQQYN2jcDgqqAZXeGgdC9CIm%2BVXokB--YW%2Bz09104%2F57%2FclJ--ZdH5IpOHir9lsqmjCkv4%2Bg%3D%3D; _forum_session=KnW1D3%2BnDDBaSwva4UejT5IxyZjG4sDaS0eGNLzV6eSy6gB9MqWoV3ZDwHAxX2YdO%2F1iOe5rDmTdY5tgZY2svtAl4lW5hS67JgSPjfkJWoywzJHZQ%2BJMy4EtJo4i125dimiznEyt%2FNOOGGJIEqFhiuL4z3gY7485LuljNo%2Fbj9GQ1%2BxPJMGMx8v7EwbAGpp%2BTy4iWLvnuOOBYLFb8sOLZgn%2FCoOiHWpZW0ZgfmrYa%2BloPUjaA5IOtP16HQ%2BT4QOr%2B2bqAusCPKVxcY%2FPgdiLU%2Bdp%2BVxRRA%3D%3D--uNQN2Yfs0pXgjf0D--iLXY9f%2BdaiZzxWI1JDGmsg%3D%3D"}
resp = requests.get(url, params=params, cookies=cookies)
resp.json()
# Out:
# {'post_stream': {'posts': [{'id': 575209,
#     'name': 'Tanya kamboj',
#     'username': '21f3000745',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/21f3000745/{size}/638_2.png',
#     'created_at': '2025-01-01T16:04:48.996Z',
#     'cooked': '<p>Hii all…i know this may not be the correct platform to ask this question.<br>\nActually i have 3 diploma subjects to cover - MLP, JAVA, TDS. So which 2 subject should i choose for this term?</p>',
#     'post_number': 1,
#     'post_type': 1,
#     'posts_count': 5,
#     'updated_at': '2025-01-01T16:04:48.996Z',
#     'reply_count': 0,
#     'reply_to_post_number': None,
#     'quote_count': 0,
#     'incoming_link_count': 3,
#     'reads': 123,
#     'readers_count': 122,
#     'score': 36.6,
#     'yours': True,
#     'topic_id': 161071,
#     'topic_slug': 'which-subject-to-choose-in-jan-term',
#     'display_username': 'Tanya kamboj',
#     'primary_group_name': 'ds-students',
# ...
